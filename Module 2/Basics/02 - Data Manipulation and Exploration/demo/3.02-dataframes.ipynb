# %% [markdown]
# # DataFrames
#
# DataFrames are the workhorse of pandas and are directly inspired by the R programming language. We can think of a DataFrame as a bunch of Series objects put together to share the same index. Let's use pandas to explore this topic!

# %%
import pandas as pd
import numpy as np

# %%
from numpy.random import randn

# %%
df = pd.DataFrame(randn(5,4),index='A B C D E'.split(),columns='W X Y Z'.split())

# %%
df
# Out:
#           W         X         Y         Z
# A -0.228288 -0.607010  0.155750  0.288619
# B -1.761849  0.200611  0.029698 -0.034792
# C -1.228366  0.165949 -2.206289  1.196588
# D -0.650531  1.614679 -1.386190 -0.540926
# E  0.064297  1.144577 -0.946163  2.338362

# %% [markdown]
# ## Selection and Indexing
#
# Let's learn the various methods to grab data from a DataFrame

# %%
df['W']
# Out:
# A   -0.228288
# B   -1.761849
# C   -1.228366
# D   -0.650531
# E    0.064297
# Name: W, dtype: float64

# %%
# Pass a list of column names
df[['W','Z']]
# Out:
#           W         Z
# A -0.228288  0.288619
# B -1.761849 -0.034792
# C -1.228366  1.196588
# D -0.650531 -0.540926
# E  0.064297  2.338362

# %%
df.W
# Out:
# A   -0.228288
# B   -1.761849
# C   -1.228366
# D   -0.650531
# E    0.064297
# Name: W, dtype: float64

# %% [markdown]
# DataFrame Columns are just Series

# %%
type(df['W'])
# Out:
# pandas.core.series.Series

# %% [markdown]
# **Creating a new column:**

# %%
df['new'] = df['W'] + df['Y']

# %%
df
# Out:
#           W         X         Y         Z       new
# A -0.228288 -0.607010  0.155750  0.288619 -0.072538
# B -1.761849  0.200611  0.029698 -0.034792 -1.732151
# C -1.228366  0.165949 -2.206289  1.196588 -3.434655
# D -0.650531  1.614679 -1.386190 -0.540926 -2.036721
# E  0.064297  1.144577 -0.946163  2.338362 -0.881866

# %% [markdown]
# ** Removing Columns**

# %%
df.drop('new',axis=1,inplace=True)

# %%
# Not inplace unless specified!
df
# Out:
#           W         X         Y         Z
# A -0.228288 -0.607010  0.155750  0.288619
# B -1.761849  0.200611  0.029698 -0.034792
# C -1.228366  0.165949 -2.206289  1.196588
# D -0.650531  1.614679 -1.386190 -0.540926
# E  0.064297  1.144577 -0.946163  2.338362

# %%
df.drop('new',axis=1,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-13-d3484050cca8> in <module>()
# ----> 1 df.drop('new',axis=1,inplace=True)
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4172             level=level,
#    4173             inplace=inplace,
# -> 4174             errors=errors,
#    4175         )
#    4176
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3885         for axis, labels in axes.items():
#    3886             if labels is not None:
# -> 3887                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3888
#    3889         if inplace:
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors)
#    3919                 new_axis = axis.drop(labels, level=level, errors=errors)
#    3920             else:
# -> 3921                 new_axis = axis.drop(labels, errors=errors)
#    3922             result = self.reindex(**{axis_name: new_axis})
#    3923
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    5282         if mask.any():
#    5283             if errors != "ignore":
# -> 5284                 raise KeyError(f"{labels[mask]} not found in axis")
#    5285             indexer = indexer[~mask]
#    5286         return self.delete(indexer)
#
# KeyError: "['new'] not found in axis"

# %%
df

# %% [markdown]
# Can also drop rows this way:

# %%
df.drop('E')
# Out:
#           W         X         Y         Z
# A -0.228288 -0.607010  0.155750  0.288619
# B -1.761849  0.200611  0.029698 -0.034792
# C -1.228366  0.165949 -2.206289  1.196588
# D -0.650531  1.614679 -1.386190 -0.540926

# %% [markdown]
# ** Selecting Rows**

# %%
df.loc['A']
# Out:
# W   -0.228288
# X   -0.607010
# Y    0.155750
# Z    0.288619
# Name: A, dtype: float64

# %% [markdown]
# Or select based off of position instead of label

# %%
df.iloc[2]
# Out:
# W   -1.228366
# X    0.165949
# Y   -2.206289
# Z    1.196588
# Name: C, dtype: float64

# %% [markdown]
# ** Selecting subset of rows and columns **

# %%
df.loc['B','Y']
# Out:
# 0.029698239615433792

# %%
df.loc[['A','B'],['W','Y']]
# Out:
#           W         Y
# A -0.228288  0.155750
# B -1.761849  0.029698

# %% [markdown]
# ### Conditional Selection
#
# An important feature of pandas is conditional selection using bracket notation, very similar to numpy:

# %%
df
# Out:
#           W         X         Y         Z
# A -0.228288 -0.607010  0.155750  0.288619
# B -1.761849  0.200611  0.029698 -0.034792
# C -1.228366  0.165949 -2.206289  1.196588
# D -0.650531  1.614679 -1.386190 -0.540926
# E  0.064297  1.144577 -0.946163  2.338362

# %%
df>0
# Out:
#        W      X      Y      Z
# A  False  False   True   True
# B  False   True   True  False
# C  False   True  False   True
# D  False   True  False  False
# E   True   True  False   True

# %%
df[df>0]
# Out:
#           W         X         Y         Z
# A       NaN       NaN  0.155750  0.288619
# B       NaN  0.200611  0.029698       NaN
# C       NaN  0.165949       NaN  1.196588
# D       NaN  1.614679       NaN       NaN
# E  0.064297  1.144577       NaN  2.338362

# %%
df[df['W']>0]
# Out:
#           W         X         Y         Z
# E  0.064297  1.144577 -0.946163  2.338362

# %%
df[df['W']>0]['Y']
# Out:
# E   -0.946163
# Name: Y, dtype: float64

# %%
df[df['W']>0][['Y','X']]
# Out:
#           Y         X
# E -0.946163  1.144577

# %% [markdown]
# For two conditions you can use | and & with parenthesis:

# %%
df[(df['W']>0) & (df['Y'] > 1)]
# Out:
# Empty DataFrame
# Columns: [W, X, Y, Z]
# Index: []

# %% [markdown]
# ## More Index Details
#
# Let's discuss some more features of indexing, including resetting the index or setting it something else. We'll also talk about index hierarchy!

# %%
df
# Out:
#           W         X         Y         Z
# A -0.228288 -0.607010  0.155750  0.288619
# B -1.761849  0.200611  0.029698 -0.034792
# C -1.228366  0.165949 -2.206289  1.196588
# D -0.650531  1.614679 -1.386190 -0.540926
# E  0.064297  1.144577 -0.946163  2.338362

# %%
newind = 'CA NY WY OR CO'.split()

# %%
df['States'] = newind

# %%
df
# Out:
#           W         X         Y         Z States
# A -0.228288 -0.607010  0.155750  0.288619     CA
# B -1.761849  0.200611  0.029698 -0.034792     NY
# C -1.228366  0.165949 -2.206289  1.196588     WY
# D -0.650531  1.614679 -1.386190 -0.540926     OR
# E  0.064297  1.144577 -0.946163  2.338362     CO

# %%
df.set_index('States')
# Out:
#                W         X         Y         Z
# States
# CA     -0.228288 -0.607010  0.155750  0.288619
# NY     -1.761849  0.200611  0.029698 -0.034792
# WY     -1.228366  0.165949 -2.206289  1.196588
# OR     -0.650531  1.614679 -1.386190 -0.540926
# CO      0.064297  1.144577 -0.946163  2.338362

# %%
df
# Out:
#           W         X         Y         Z States
# A -0.228288 -0.607010  0.155750  0.288619     CA
# B -1.761849  0.200611  0.029698 -0.034792     NY
# C -1.228366  0.165949 -2.206289  1.196588     WY
# D -0.650531  1.614679 -1.386190 -0.540926     OR
# E  0.064297  1.144577 -0.946163  2.338362     CO

# %%
df.set_index('States',inplace=True)

# %%
df
# Out:
#                W         X         Y         Z
# States
# CA     -0.228288 -0.607010  0.155750  0.288619
# NY     -1.761849  0.200611  0.029698 -0.034792
# WY     -1.228366  0.165949 -2.206289  1.196588
# OR     -0.650531  1.614679 -1.386190 -0.540926
# CO      0.064297  1.144577 -0.946163  2.338362
