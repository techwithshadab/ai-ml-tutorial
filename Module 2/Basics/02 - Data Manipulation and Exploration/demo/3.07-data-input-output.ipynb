# %% [markdown]
# # Data Input and Output
#
# This notebook is the reference code for getting input and output, pandas can read a variety of file types using its pd.read_ methods. Let's take a look at the most common data types:

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-33238900-481b-480e-bc74-fc7301fb1ecd" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-33238900-481b-480e-bc74-fc7301fb1ecd">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Excel_Sample.xlsx to Excel_Sample.xlsx

# %%
import numpy as np
import pandas as pd
import sys

# %%
# !ls
# Out:
# drive  Excel_Sample.xlsx  sample_data

# %% [markdown]
# ## CSV
#
# ### CSV Input

# %%
df = pd.read_excel('Excel_Sample.xlsx')
df
# Out:
#    Unnamed: 0   a   b   c   d
# 0           0   0   1   2   3
# 1           1   4   5   6   7
# 2           2   8   9  10  11
# 3           3  12  13  14  15

# %% [markdown]
# ### CSV Output

# %%
df.to_csv('example',index=False)

# %% [markdown]
# ## Excel
# Pandas can read and write excel files, keep in mind, this only imports data. Not formulas or images, having images or macros may cause this read_excel method to crash.

# %%
# !pip install xlrd
# !pip install openpyxl
# Out:
# Requirement already satisfied: xlrd in /usr/local/lib/python3.6/dist-packages (1.1.0)
# Requirement already satisfied: openpyxl in /usr/local/lib/python3.6/dist-packages (2.5.9)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.6/dist-packages (from openpyxl) (1.0.1)
# Requirement already satisfied: jdcal in /usr/local/lib/python3.6/dist-packages (from openpyxl) (1.4.1)

# %% [markdown]
# ### Excel Input

# %%
pd.read_excel('Excel_Sample.xlsx',sheet_name='Sheet1')
# Out:
#    Unnamed: 0   a   b   c   d
# 0           0   0   1   2   3
# 1           1   4   5   6   7
# 2           2   8   9  10  11
# 3           3  12  13  14  15

# %% [markdown]
# ### Excel Output

# %%
df.to_excel('Excel_Sample.xlsx',sheet_name='Sheet1')
